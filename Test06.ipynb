# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
class Config(object):
    def __init__(self, dataset, embedding):
        self.model_name = 'TextRNN'
        self.train_path = dataset + 'data/train.txt'
        self.dev_path = dataset + 'data/dev.txt'
        self.test_path = dataset + 'data/test.txt'
        self.class_list = [x.strip() for x in open(
            dataset + 'data/class.txt'
        ).readlines()]
        
        self.vocab_path = dataset + 'data/vocab.pkl'
        self.save_pat = dataset + 'data/saved_dict/' + self.model_name + '.ckpt'
        self.embedding_pretrained = torch.tensor(
            np.load(dataset + '/data/' + embedding)['embeddings'].astype('float32')\
            if embedding != 'random' else None
        )
        
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        self.dropout = 0.5
        self.require_improvement = 1000
        self.num_classes = len(self.class_list)
        self.n_vocab = 0
        self.num_epochs = 10
        self.batch_size = 128
        self.pad_size = 32
        self.learning_rate = 1e-3
        self.embed = self.embedding_pretrained.size(1)\
            if self.embedding_pretrained is not None else 300
        self.hidden_size = 128
        
        self.num_layers = 2

class TextRNN(nn.Module):
    def __init__(self, embedding_pretrained, num_classes):
        super(TextRNN, self).__init__()
        if embedding_pretrained is not None:
            self.embedding = nn.Embedding.from_pretrained(embedding_pretrained, freeze=False)
            
        else:
            raise 'not pretrained embedding'
#         else:
#             self.embedding = nn.Embedding(config.n_vocab, config.embed, padding_idx=config.n_vocab-1)

            
        self.lstm = nn.LSTM(embedding_pretrained.size(1), 128, 2,
                           bidirectional=True, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(128 * 2, num_classes)
        
    def forward(self, x):
        x, _ = x
        out = self.embedding(x)
        out, _ = self.lstm(out)
        out = self.fc(out[:, -1, :])
        return out

# %%
def build_dataset(config, ues_word):
    if ues_word:
        tokenizer = lambda x: x.split(' ')  # 以空格隔开，word-level
    else:
        tokenizer = lambda x: [y for y in x]  # char-level
    if os.path.exists(config.vocab_path):
        vocab = pkl.load(open(config.vocab_path, 'rb'))
    else:
        vocab = build_vocab(config.train_path, tokenizer=tokenizer, max_size=MAX_VOCAB_SIZE, min_freq=1)
        pkl.dump(vocab, open(config.vocab_path, 'wb'))
    print(f"Vocab size: {len(vocab)}")

    def biGramHash(sequence, t, buckets):
        t1 = sequence[t - 1] if t - 1 >= 0 else 0
        return (t1 * 14918087) % buckets

    def triGramHash(sequence, t, buckets):
        t1 = sequence[t - 1] if t - 1 >= 0 else 0
        t2 = sequence[t - 2] if t - 2 >= 0 else 0
        return (t2 * 14918087 * 18408749 + t1 * 14918087) % buckets

    def load_dataset(path, pad_size=32):
        contents = []
        with open(path, 'r', encoding='UTF-8') as f:
            for line in tqdm(f):
                lin = line.strip()
                if not lin:
                    continue
                content, label = lin.split('\t')
                words_line = []
                token = tokenizer(content)
                seq_len = len(token)
                if pad_size:
                    if len(token) < pad_size:
                        token.extend([vocab.get(PAD)] * (pad_size - len(token)))
                    else:
                        token = token[:pad_size]
                        seq_len = pad_size
                # word to id
                for word in token:
                    words_line.append(vocab.get(word, vocab.get(UNK)))

                # fasttext ngram
                buckets = config.n_gram_vocab
                bigram = []
                trigram = []
                # ------ngram------
                for i in range(pad_size):
                    bigram.append(biGramHash(words_line, i, buckets))
                    trigram.append(triGramHash(words_line, i, buckets))
                # -----------------
                contents.append((words_line, int(label), seq_len, bigram, trigram))
        return contents  # [([...], 0), ([...], 1), ...]
    train = load_dataset(config.train_path, config.pad_size)
    dev = load_dataset(config.dev_path, config.pad_size)
    test = load_dataset(config.test_path, config.pad_size)
    return vocab, train, dev, test

# %%
import pickle as pkl
vocab = pkl.load(open('./rnn_data/vocab.pkl','rb'))
len(vocab)
# Out:
# 4762

# %%
from tqdm import tqdm

def load_dataset(path, pad_size=32):
    contents = []
    with open(path, 'r', encoding='UTF-8') as f:
        for line in tqdm(f):
            lin = line.strip()
            if not lin:
                continue
            content, label = lin.split('\t')
            words_line = []
            token = [x for x in content]
            seq_len = len(token)
            if pad_size:
                if len(token) < pad_size:
                    token.extend([vocab.get('<PAD>')] * (pad_size - len(token)))
                else:
                    token = token[:pad_size]
                    seq_len = pad_size
            # word to id
            for word in token:
                words_line.append(vocab.get(word, vocab.get('<UNK>')))
            contents.append((words_line, int(label), seq_len))
    return contents  # [([...], 0), ([...], 1), ...]

# %%
train_ds = load_dataset('./rnn_data/train.txt')
dev_ds = load_dataset('./rnn_data/dev.txt')
test_ds = load_dataset('./rnn_data/test.txt')
# Out:
# 180000it [00:01, 128525.50it/s]
# 10000it [00:00, 54538.63it/s]
# 10000it [00:00, 157919.86it/s]

# %%
class DatasetIterater(object):
    def __init__(self, batches, batch_size, device):
        self.batches = batches
        self.batch_size = batch_size
        self.n_batches = len(batches) // batch_size
        self.residue = (len(batches) % batch_size == 0)
        
        self.index = 0
        self.device = device
        
    def _to_tensor(self, datas):
        x = torch.LongTensor([_[0] for _ in datas]).to(self.device)
        y = torch.LongTensor([_[1] for _ in datas]).to(self.device)
        seq_len = torch.LongTensor([len(_[0]) for _ in datas]).to(self.device)
        
        return (x, seq_len),y
    
    def __next__(self):
        if self.residue and self.index == self.n_batches:
            batches = self.batches[self.index*self.batch_size : len(self.batches)]
            self.index += 1
            batches = self._to_tensor(batches)
            return batches
        
        if self.index > self.n_batches:
            self.index = 0
            raise StopIteration
            pass
        else:
            batches = self.batches[self.index*self.batch_size: (self.index+1)*self.batch_size]
            batches = self._to_tensor(batches)
            self.index += 1
#             print('n',batches)
            return batches
    
    def __iter__(self):
        return self
    
    def __len__(self):
        return self.n_batches + (1 if self.residue else 0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_dl = DatasetIterater(train_ds, batch_size=128, device=device)
dev_dl = DatasetIterater(dev_ds, batch_size=128, device=device)
test_dl = DatasetIterater(test_ds, batch_size=128, device=device)

# %%
embeding_pretrained = torch.tensor(
    np.load('./rnn_data/embedding_Tencent.npz')['embeddings'].astype('float32')
)
embeding_pretrained.shape
class_list = [x.strip() for x in open(
        './rnn_data/class.txt'
    ).readlines()]
class_list
num_classes = len(class_list)


model_rt = TextRNN(embeding_pretrained, num_classes)
model_rt = model_rt.to(device)

# %%
dataset = 'THUCNews'

embedding = 'embedding_SougouNews.npz'
model_name = 'TextRNN'

config = Config(dataset, embedding)
np.random.seed(1)
torch.manual_seed(1)
torch.cuda.manual_seed_all(1)
torch.backends.cudnn.deterministic = True

import time
start_time = time.time()
print('Load data ...')

# %%
from sklearn import metrics

def train(model, train_dl, dev_dl,epoches, writer = None):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    total_batch = 0
    for epoch in (range(epoches)):
        print('{}/{}'.format(epoch, epoches))
        
        for x, labels in train_dl:
            model.train()
            outputs = model(x)
            loss = F.cross_entropy(outputs, labels)
            optimizer.zero_grad()  # TODO ???
            loss.backward()
            optimizer.step()
            
            if total_batch % 100 == 0:
                true = labels.data.cpu()
                predict = torch.max(outputs.data, 1)[1].cpu()
#                 print(true)
#                 print(predict)
                train_acc = metrics.accuracy_score(true, predict)
                print('train_acc = {:.4f}'.format(train_acc))
                dev_acc, dev_loss = evalute(model, dev_dl )
                print('dev_acc = {:.4f}, dev_loss={:.4f}'.format(dev_acc, dev_loss))
                if writer is not None:
                    writer.add_scalar('loss/train', loss.item(), total_batch)
                    writer.add_scalar('loss/dev', dev_loss, total_batch)
                    writer.add_scalar('acc/train', train_acc, total_batch)
                    writer.add_scalar('acc/dev', dev_acc, total_batch)
                
            total_batch += 1

# %%
from tensorboardX import SummaryWriter
import time
writer = SummaryWriter(log_dir='./log/' + time.strftime('%m-%d_%H.%M', time.localtime()))

train(model_rt, train_dl, dev_dl,100, writer)
# type(train_dl)
# for x, y in train_dl:
#     print(y)
# Out:
# 0/100
# train_acc = 1.0000
# dev_acc = 0.8855, dev_loss=0.6683
# train_acc = 0.9844
# dev_acc = 0.8882, dev_loss=0.6510
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.6322
# train_acc = 0.9844
# dev_acc = 0.8854, dev_loss=0.6910
# train_acc = 0.9844
# dev_acc = 0.8878, dev_loss=0.6773
# train_acc = 0.9922
# dev_acc = 0.8871, dev_loss=0.6927
# train_acc = 0.9844
# dev_acc = 0.8855, dev_loss=0.6654
# train_acc = 0.9609
# dev_acc = 0.8859, dev_loss=0.6355
# train_acc = 0.9922
# dev_acc = 0.8872, dev_loss=0.6720
# train_acc = 0.9844
# dev_acc = 0.8845, dev_loss=0.6962
# train_acc = 0.9844
# dev_acc = 0.8837, dev_loss=0.6584
# 1/100
# train_acc = 1.0000
# dev_acc = 0.8859, dev_loss=0.6824
# train_acc = 0.9922
# dev_acc = 0.8866, dev_loss=0.6924
# train_acc = 0.9922
# dev_acc = 0.8861, dev_loss=0.6552
# train_acc = 0.9922
# dev_acc = 0.8866, dev_loss=0.6683
# train_acc = 1.0000
# dev_acc = 0.8850, dev_loss=0.6979
# train_acc = 0.9766
# dev_acc = 0.8847, dev_loss=0.6766
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.6813
# train_acc = 0.9844
# dev_acc = 0.8865, dev_loss=0.6725
# train_acc = 0.9922
# dev_acc = 0.8832, dev_loss=0.6982
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.6446
# train_acc = 0.9922
# dev_acc = 0.8847, dev_loss=0.6839
# train_acc = 0.9922
# dev_acc = 0.8852, dev_loss=0.6805
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.6574
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.6819
# 2/100
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.6649
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.6536
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.6416
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.6595
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.6801
# train_acc = 0.9766
# dev_acc = 0.8856, dev_loss=0.6588
# train_acc = 0.9688
# dev_acc = 0.8819, dev_loss=0.6881
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.6714
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6695
# train_acc = 0.9844
# dev_acc = 0.8883, dev_loss=0.6489
# train_acc = 0.9922
# dev_acc = 0.8895, dev_loss=0.6629
# train_acc = 0.9844
# dev_acc = 0.8880, dev_loss=0.6591
# train_acc = 1.0000
# dev_acc = 0.8854, dev_loss=0.6742
# train_acc = 0.9766
# dev_acc = 0.8844, dev_loss=0.6794
# 3/100
# train_acc = 0.9922
# dev_acc = 0.8866, dev_loss=0.6618
# train_acc = 0.9844
# dev_acc = 0.8867, dev_loss=0.6810
# train_acc = 0.9844
# dev_acc = 0.8891, dev_loss=0.6402
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.6759
# train_acc = 1.0000
# dev_acc = 0.8829, dev_loss=0.6988
# train_acc = 0.9844
# dev_acc = 0.8853, dev_loss=0.6850
# train_acc = 1.0000
# dev_acc = 0.8844, dev_loss=0.6862
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.6843
# train_acc = 1.0000
# dev_acc = 0.8869, dev_loss=0.6721
# train_acc = 0.9688
# dev_acc = 0.8895, dev_loss=0.6605
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.6590
# train_acc = 0.9688
# dev_acc = 0.8852, dev_loss=0.6820
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.6875
# train_acc = 0.9844
# dev_acc = 0.8857, dev_loss=0.6582
# 4/100
# train_acc = 0.9922
# dev_acc = 0.8879, dev_loss=0.6614
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.6801
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.6642
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.6885
# train_acc = 0.9844
# dev_acc = 0.8822, dev_loss=0.7097
# train_acc = 1.0000
# dev_acc = 0.8868, dev_loss=0.6701
# train_acc = 0.9844
# dev_acc = 0.8880, dev_loss=0.6839
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6781
# train_acc = 1.0000
# dev_acc = 0.8845, dev_loss=0.6773
# train_acc = 0.9766
# dev_acc = 0.8869, dev_loss=0.6629
# train_acc = 0.9844
# dev_acc = 0.8837, dev_loss=0.6907
# train_acc = 0.9922
# dev_acc = 0.8880, dev_loss=0.6488
# train_acc = 0.9844
# dev_acc = 0.8864, dev_loss=0.6774
# train_acc = 0.9922
# dev_acc = 0.8864, dev_loss=0.6573
# 5/100
# train_acc = 0.9844
# dev_acc = 0.8852, dev_loss=0.6578
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.6659
# train_acc = 0.9688
# dev_acc = 0.8859, dev_loss=0.6622
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6767
# train_acc = 0.9922
# dev_acc = 0.8869, dev_loss=0.6954
# train_acc = 0.9766
# dev_acc = 0.8857, dev_loss=0.6806
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.6639
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7022
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.6877
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.6794
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7037
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7031
# train_acc = 0.9922
# dev_acc = 0.8877, dev_loss=0.6956
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.6435
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.6694
# 6/100
# train_acc = 0.9844
# dev_acc = 0.8888, dev_loss=0.6619
# train_acc = 0.9922
# dev_acc = 0.8890, dev_loss=0.6455
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.6613
# train_acc = 0.9922
# dev_acc = 0.8870, dev_loss=0.6979
# train_acc = 0.9922
# dev_acc = 0.8873, dev_loss=0.6812
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.6771
# train_acc = 0.9844
# dev_acc = 0.8859, dev_loss=0.6925
# train_acc = 0.9922
# dev_acc = 0.8873, dev_loss=0.6726
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.6645
# train_acc = 0.9844
# dev_acc = 0.8846, dev_loss=0.7100
# train_acc = 0.9922
# dev_acc = 0.8856, dev_loss=0.6937
# train_acc = 0.9766
# dev_acc = 0.8859, dev_loss=0.6893
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.6766
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6922
# 7/100
# train_acc = 0.9922
# dev_acc = 0.8870, dev_loss=0.7090
# train_acc = 0.9844
# dev_acc = 0.8859, dev_loss=0.6948
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.6757
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.6568
# train_acc = 0.9688
# dev_acc = 0.8913, dev_loss=0.6952
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.6765
# train_acc = 0.9922
# dev_acc = 0.8897, dev_loss=0.6835
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.6916
# train_acc = 0.9844
# dev_acc = 0.8877, dev_loss=0.6622
# train_acc = 1.0000
# dev_acc = 0.8849, dev_loss=0.6913
# train_acc = 0.9766
# dev_acc = 0.8859, dev_loss=0.6729
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.6926
# train_acc = 0.9922
# dev_acc = 0.8854, dev_loss=0.6826
# train_acc = 0.9922
# dev_acc = 0.8839, dev_loss=0.6976
# 8/100
# train_acc = 1.0000
# dev_acc = 0.8856, dev_loss=0.6934
# train_acc = 0.9766
# dev_acc = 0.8861, dev_loss=0.7041
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7004
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.6896
# train_acc = 0.9844
# dev_acc = 0.8881, dev_loss=0.6884
# train_acc = 0.9844
# dev_acc = 0.8851, dev_loss=0.6835
# train_acc = 1.0000
# dev_acc = 0.8863, dev_loss=0.6929
# train_acc = 1.0000
# dev_acc = 0.8848, dev_loss=0.6695
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.6807
# train_acc = 0.9922
# dev_acc = 0.8849, dev_loss=0.7076
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7014
# train_acc = 0.9922
# dev_acc = 0.8839, dev_loss=0.7270
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7265
# train_acc = 0.9922
# dev_acc = 0.8860, dev_loss=0.7035
# 9/100
# train_acc = 1.0000
# dev_acc = 0.8839, dev_loss=0.7000
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.7046
# train_acc = 0.9922
# dev_acc = 0.8846, dev_loss=0.7111
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.6968
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.6917
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6952
# train_acc = 0.9922
# dev_acc = 0.8862, dev_loss=0.7142
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.6948
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.6885
# train_acc = 1.0000
# dev_acc = 0.8870, dev_loss=0.7029
# train_acc = 1.0000
# dev_acc = 0.8838, dev_loss=0.6931
# train_acc = 0.9922
# dev_acc = 0.8827, dev_loss=0.7306
# train_acc = 1.0000
# dev_acc = 0.8855, dev_loss=0.7151
# train_acc = 0.9844
# dev_acc = 0.8844, dev_loss=0.6915
# 10/100
# train_acc = 0.9922
# dev_acc = 0.8854, dev_loss=0.7167
# train_acc = 1.0000
# dev_acc = 0.8837, dev_loss=0.6845
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.6951
# train_acc = 0.9922
# dev_acc = 0.8863, dev_loss=0.7191
# train_acc = 0.9922
# dev_acc = 0.8846, dev_loss=0.7133
# train_acc = 0.9922
# dev_acc = 0.8843, dev_loss=0.6940
# train_acc = 0.9766
# dev_acc = 0.8835, dev_loss=0.7050
# train_acc = 0.9844
# dev_acc = 0.8874, dev_loss=0.6823
# train_acc = 0.9844
# dev_acc = 0.8849, dev_loss=0.6907
# train_acc = 0.9844
# dev_acc = 0.8888, dev_loss=0.6816
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.6846
# train_acc = 0.9766
# dev_acc = 0.8872, dev_loss=0.7157
# train_acc = 1.0000
# dev_acc = 0.8858, dev_loss=0.7103
# train_acc = 0.9766
# dev_acc = 0.8860, dev_loss=0.7040
# 11/100
# train_acc = 0.9844
# dev_acc = 0.8855, dev_loss=0.7093
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.6978
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.6753
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.6712
# train_acc = 1.0000
# dev_acc = 0.8839, dev_loss=0.7041
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.6760
# train_acc = 1.0000
# dev_acc = 0.8851, dev_loss=0.7031
# train_acc = 0.9844
# dev_acc = 0.8875, dev_loss=0.6804
# train_acc = 0.9844
# dev_acc = 0.8882, dev_loss=0.6963
# train_acc = 0.9844
# dev_acc = 0.8880, dev_loss=0.6898
# train_acc = 0.9922
# dev_acc = 0.8872, dev_loss=0.6837
# train_acc = 0.9844
# dev_acc = 0.8866, dev_loss=0.7096
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7181
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7058
# 12/100
# train_acc = 1.0000
# dev_acc = 0.8834, dev_loss=0.7167
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.7253
# train_acc = 0.9922
# dev_acc = 0.8872, dev_loss=0.7228
# train_acc = 0.9922
# dev_acc = 0.8850, dev_loss=0.7585
# train_acc = 0.9922
# dev_acc = 0.8852, dev_loss=0.7053
# train_acc = 0.9844
# dev_acc = 0.8838, dev_loss=0.6971
# train_acc = 1.0000
# dev_acc = 0.8835, dev_loss=0.7302
# train_acc = 0.9844
# dev_acc = 0.8858, dev_loss=0.7162
# train_acc = 1.0000
# dev_acc = 0.8815, dev_loss=0.7240
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.6676
# train_acc = 1.0000
# dev_acc = 0.8862, dev_loss=0.6893
# train_acc = 0.9844
# dev_acc = 0.8870, dev_loss=0.6860
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.6947
# train_acc = 1.0000
# dev_acc = 0.8847, dev_loss=0.6938
# 13/100
# train_acc = 1.0000
# dev_acc = 0.8873, dev_loss=0.7100
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7011
# train_acc = 1.0000
# dev_acc = 0.8862, dev_loss=0.7250
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.7089
# train_acc = 1.0000
# dev_acc = 0.8862, dev_loss=0.7119
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.6720
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.7062
# train_acc = 1.0000
# dev_acc = 0.8926, dev_loss=0.7030
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7005
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.6991
# train_acc = 0.9766
# dev_acc = 0.8883, dev_loss=0.6703
# train_acc = 0.9922
# dev_acc = 0.8866, dev_loss=0.6938
# train_acc = 0.9844
# dev_acc = 0.8896, dev_loss=0.7049
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7043
# 14/100
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.6986
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.7082
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7257
# train_acc = 0.9844
# dev_acc = 0.8902, dev_loss=0.7007
# train_acc = 1.0000
# dev_acc = 0.8869, dev_loss=0.7156
# train_acc = 0.9844
# dev_acc = 0.8878, dev_loss=0.6912
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7076
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.6998
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7158
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7259
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7108
# train_acc = 0.9922
# dev_acc = 0.8890, dev_loss=0.7032
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7134
# train_acc = 0.9922
# dev_acc = 0.8855, dev_loss=0.7100
# 15/100
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.6962
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7116
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.6958
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7117
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7226
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.6827
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7143
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7119
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7300
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7297
# train_acc = 0.9766
# dev_acc = 0.8865, dev_loss=0.7246
# train_acc = 0.9922
# dev_acc = 0.8877, dev_loss=0.7278
# train_acc = 0.9922
# dev_acc = 0.8855, dev_loss=0.7527
# train_acc = 1.0000
# dev_acc = 0.8850, dev_loss=0.7365
# 16/100
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.7190
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7477
# train_acc = 0.9922
# dev_acc = 0.8863, dev_loss=0.7275
# train_acc = 0.9844
# dev_acc = 0.8871, dev_loss=0.7324
# train_acc = 1.0000
# dev_acc = 0.8853, dev_loss=0.7404
# train_acc = 1.0000
# dev_acc = 0.8834, dev_loss=0.7076
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.7221
# train_acc = 1.0000
# dev_acc = 0.8855, dev_loss=0.7345
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.6925
# train_acc = 0.9844
# dev_acc = 0.8873, dev_loss=0.7170
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7026
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.7055
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7254
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7177
# 17/100
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7051
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7249
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7071
# train_acc = 0.9922
# dev_acc = 0.8836, dev_loss=0.7705
# train_acc = 0.9844
# dev_acc = 0.8832, dev_loss=0.7563
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7495
# train_acc = 0.9922
# dev_acc = 0.8876, dev_loss=0.7220
# train_acc = 0.9688
# dev_acc = 0.8841, dev_loss=0.7355
# train_acc = 0.9922
# dev_acc = 0.8856, dev_loss=0.7330
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.7101
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7152
# train_acc = 1.0000
# dev_acc = 0.8856, dev_loss=0.7047
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7456
# train_acc = 1.0000
# dev_acc = 0.8856, dev_loss=0.7081
# 18/100
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7262
# train_acc = 1.0000
# dev_acc = 0.8868, dev_loss=0.7583
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7096
# train_acc = 1.0000
# dev_acc = 0.8866, dev_loss=0.7320
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7475
# train_acc = 1.0000
# dev_acc = 0.8851, dev_loss=0.7293
# train_acc = 0.9844
# dev_acc = 0.8896, dev_loss=0.7259
# train_acc = 0.9922
# dev_acc = 0.8880, dev_loss=0.7718
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7488
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7379
# train_acc = 0.9922
# dev_acc = 0.8890, dev_loss=0.7116
# train_acc = 0.9922
# dev_acc = 0.8871, dev_loss=0.7023
# train_acc = 0.9766
# dev_acc = 0.8845, dev_loss=0.7435
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7337
# 19/100
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7399
# train_acc = 0.9922
# dev_acc = 0.8855, dev_loss=0.7361
# train_acc = 1.0000
# dev_acc = 0.8858, dev_loss=0.7160
# train_acc = 0.9922
# dev_acc = 0.8863, dev_loss=0.7493
# train_acc = 1.0000
# dev_acc = 0.8852, dev_loss=0.7384
# train_acc = 1.0000
# dev_acc = 0.8870, dev_loss=0.7173
# train_acc = 1.0000
# dev_acc = 0.8863, dev_loss=0.7272
# train_acc = 1.0000
# dev_acc = 0.8866, dev_loss=0.7293
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7501
# train_acc = 1.0000
# dev_acc = 0.8849, dev_loss=0.7508
# train_acc = 0.9922
# dev_acc = 0.8852, dev_loss=0.7237
# train_acc = 0.9922
# dev_acc = 0.8860, dev_loss=0.7041
# train_acc = 0.9922
# dev_acc = 0.8856, dev_loss=0.7249
# train_acc = 0.9844
# dev_acc = 0.8855, dev_loss=0.7190
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7152
# 20/100
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7171
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.6979
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7171
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7392
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7289
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7099
# train_acc = 0.9844
# dev_acc = 0.8890, dev_loss=0.7170
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7177
# train_acc = 1.0000
# dev_acc = 0.8856, dev_loss=0.7024
# train_acc = 0.9922
# dev_acc = 0.8870, dev_loss=0.7096
# train_acc = 0.9922
# dev_acc = 0.8872, dev_loss=0.6988
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7231
# train_acc = 1.0000
# dev_acc = 0.8863, dev_loss=0.7227
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7171
# 21/100
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7123
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7201
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7140
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7295
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7386
# train_acc = 0.9844
# dev_acc = 0.8863, dev_loss=0.7223
# train_acc = 0.9922
# dev_acc = 0.8899, dev_loss=0.7082
# train_acc = 0.9844
# dev_acc = 0.8909, dev_loss=0.7311
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7124
# train_acc = 0.9844
# dev_acc = 0.8884, dev_loss=0.7179
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7331
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.7185
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.6976
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.6910
# 22/100
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7169
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.6963
# train_acc = 1.0000
# dev_acc = 0.8858, dev_loss=0.7093
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7312
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7294
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7362
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7202
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.7271
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.6931
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7004
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.6853
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.6937
# train_acc = 0.9844
# dev_acc = 0.8865, dev_loss=0.7508
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7279
# 23/100
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7324
# train_acc = 0.9844
# dev_acc = 0.8910, dev_loss=0.7238
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7347
# train_acc = 0.9844
# dev_acc = 0.8881, dev_loss=0.7309
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.6877
# train_acc = 1.0000
# dev_acc = 0.8913, dev_loss=0.6853
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7012
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7255
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.7154
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.6917
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7079
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7116
# train_acc = 1.0000
# dev_acc = 0.8913, dev_loss=0.7142
# train_acc = 1.0000
# dev_acc = 0.8926, dev_loss=0.7315
# 24/100
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7380
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.7466
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.7212
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7275
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7454
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7287
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7436
# train_acc = 1.0000
# dev_acc = 0.8926, dev_loss=0.7063
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7473
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7175
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.7093
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7228
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7353
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7079
# 25/100
# train_acc = 0.9844
# dev_acc = 0.8882, dev_loss=0.7154
# train_acc = 0.9922
# dev_acc = 0.8884, dev_loss=0.7101
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7360
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7389
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7233
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7050
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7153
# train_acc = 0.9922
# dev_acc = 0.8888, dev_loss=0.7260
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7323
# train_acc = 0.9922
# dev_acc = 0.8865, dev_loss=0.7061
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7009
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.7022
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7206
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7476
# 26/100
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7224
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7168
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7122
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7425
# train_acc = 0.9844
# dev_acc = 0.8925, dev_loss=0.7627
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7366
# train_acc = 0.9922
# dev_acc = 0.8895, dev_loss=0.7324
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7319
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7557
# train_acc = 0.9922
# dev_acc = 0.8880, dev_loss=0.7816
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7305
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7219
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7500
# train_acc = 0.9922
# dev_acc = 0.8865, dev_loss=0.7597
# 27/100
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7252
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7553
# train_acc = 0.9844
# dev_acc = 0.8911, dev_loss=0.7184
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7343
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7558
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7159
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7610
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7606
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7360
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7342
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7523
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7358
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7601
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7444
# 28/100
# train_acc = 1.0000
# dev_acc = 0.8922, dev_loss=0.7556
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7390
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7000
# train_acc = 0.9922
# dev_acc = 0.8895, dev_loss=0.7073
# train_acc = 0.9766
# dev_acc = 0.8915, dev_loss=0.7260
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.6885
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7172
# train_acc = 0.9922
# dev_acc = 0.8888, dev_loss=0.7272
# train_acc = 0.9766
# dev_acc = 0.8920, dev_loss=0.7372
# train_acc = 0.9922
# dev_acc = 0.8914, dev_loss=0.7238
# train_acc = 0.9766
# dev_acc = 0.8924, dev_loss=0.7072
# train_acc = 1.0000
# dev_acc = 0.8929, dev_loss=0.7163
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7230
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7130
# 29/100
# train_acc = 1.0000
# dev_acc = 0.8932, dev_loss=0.7165
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7474
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7350
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7125
# train_acc = 1.0000
# dev_acc = 0.8923, dev_loss=0.7095
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7039
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7369
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7349
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7188
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7385
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7622
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7321
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7327
# train_acc = 1.0000
# dev_acc = 0.8920, dev_loss=0.7240
# 30/100
# train_acc = 0.9922
# dev_acc = 0.8910, dev_loss=0.7258
# train_acc = 0.9922
# dev_acc = 0.8899, dev_loss=0.7113
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7384
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7255
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7317
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7501
# train_acc = 0.9844
# dev_acc = 0.8902, dev_loss=0.7355
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7536
# train_acc = 1.0000
# dev_acc = 0.8930, dev_loss=0.7189
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7334
# train_acc = 0.9922
# dev_acc = 0.8927, dev_loss=0.7348
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7272
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7409
# train_acc = 0.9922
# dev_acc = 0.8906, dev_loss=0.7241
# 31/100
# train_acc = 0.9922
# dev_acc = 0.8884, dev_loss=0.7612
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7798
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7486
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7479
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.7690
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7540
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7472
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7547
# train_acc = 1.0000
# dev_acc = 0.8866, dev_loss=0.7426
# train_acc = 0.9922
# dev_acc = 0.8869, dev_loss=0.7378
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7272
# train_acc = 0.9922
# dev_acc = 0.8862, dev_loss=0.7308
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7169
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7397
# 32/100
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7464
# train_acc = 0.9922
# dev_acc = 0.8904, dev_loss=0.7015
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7395
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7224
# train_acc = 0.9922
# dev_acc = 0.8905, dev_loss=0.7429
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7380
# train_acc = 0.9844
# dev_acc = 0.8913, dev_loss=0.7398
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7502
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7168
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7399
# train_acc = 0.9922
# dev_acc = 0.8917, dev_loss=0.7386
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7428
# train_acc = 0.9844
# dev_acc = 0.8862, dev_loss=0.7341
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7657
# 33/100
# train_acc = 0.9844
# dev_acc = 0.8882, dev_loss=0.7476
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.7515
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7485
# train_acc = 0.9844
# dev_acc = 0.8889, dev_loss=0.7371
# train_acc = 0.9922
# dev_acc = 0.8888, dev_loss=0.7401
# train_acc = 0.9922
# dev_acc = 0.8888, dev_loss=0.7603
# train_acc = 0.9922
# dev_acc = 0.8880, dev_loss=0.7529
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7727
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.7873
# train_acc = 1.0000
# dev_acc = 0.8856, dev_loss=0.7962
# train_acc = 0.9844
# dev_acc = 0.8875, dev_loss=0.7588
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7669
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7293
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7367
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7387
# 34/100
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7396
# train_acc = 0.9922
# dev_acc = 0.8904, dev_loss=0.7372
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7473
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7738
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7352
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7417
# train_acc = 0.9844
# dev_acc = 0.8867, dev_loss=0.7552
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7190
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7311
# train_acc = 0.9844
# dev_acc = 0.8921, dev_loss=0.7204
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.7380
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7205
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7507
# train_acc = 0.9922
# dev_acc = 0.8881, dev_loss=0.7661
# 35/100
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7736
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7803
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7476
# train_acc = 1.0000
# dev_acc = 0.8926, dev_loss=0.7437
# train_acc = 1.0000
# dev_acc = 0.8934, dev_loss=0.7487
# train_acc = 0.9844
# dev_acc = 0.8899, dev_loss=0.7280
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7325
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7390
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7458
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7611
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7512
# train_acc = 0.9922
# dev_acc = 0.8877, dev_loss=0.7679
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7422
# train_acc = 0.9922
# dev_acc = 0.8899, dev_loss=0.7284
# 36/100
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7128
# train_acc = 0.9922
# dev_acc = 0.8880, dev_loss=0.7296
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7289
# train_acc = 0.9922
# dev_acc = 0.8869, dev_loss=0.7504
# train_acc = 0.9844
# dev_acc = 0.8895, dev_loss=0.7334
# train_acc = 0.9922
# dev_acc = 0.8865, dev_loss=0.7269
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7161
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7338
# train_acc = 0.9922
# dev_acc = 0.8919, dev_loss=0.7138
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7140
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.7116
# train_acc = 0.9922
# dev_acc = 0.8917, dev_loss=0.7255
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.7238
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7300
# 37/100
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7471
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7400
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7497
# train_acc = 0.9922
# dev_acc = 0.8916, dev_loss=0.7352
# train_acc = 0.9922
# dev_acc = 0.8910, dev_loss=0.7460
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7233
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7550
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7567
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7259
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7489
# train_acc = 0.9844
# dev_acc = 0.8867, dev_loss=0.7475
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7699
# train_acc = 0.9922
# dev_acc = 0.8894, dev_loss=0.7520
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7555
# 38/100
# train_acc = 0.9922
# dev_acc = 0.8871, dev_loss=0.7637
# train_acc = 0.9922
# dev_acc = 0.8884, dev_loss=0.7459
# train_acc = 1.0000
# dev_acc = 0.8873, dev_loss=0.7646
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7673
# train_acc = 0.9922
# dev_acc = 0.8881, dev_loss=0.7462
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7336
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7536
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7519
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7505
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7225
# train_acc = 1.0000
# dev_acc = 0.8869, dev_loss=0.7499
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.7372
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7461
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7382
# 39/100
# train_acc = 0.9922
# dev_acc = 0.8884, dev_loss=0.7509
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7402
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7349
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7192
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7501
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7524
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7307
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7359
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7302
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7164
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7371
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7300
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7312
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7096
# 40/100
# train_acc = 0.9922
# dev_acc = 0.8897, dev_loss=0.7289
# train_acc = 0.9844
# dev_acc = 0.8909, dev_loss=0.7458
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7220
# train_acc = 0.9922
# dev_acc = 0.8925, dev_loss=0.7318
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7135
# train_acc = 1.0000
# dev_acc = 0.8939, dev_loss=0.7250
# train_acc = 1.0000
# dev_acc = 0.8913, dev_loss=0.7099
# train_acc = 0.9844
# dev_acc = 0.8909, dev_loss=0.7328
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7137
# train_acc = 1.0000
# dev_acc = 0.8873, dev_loss=0.7568
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7390
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7394
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7301
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7265
# 41/100
# train_acc = 0.9922
# dev_acc = 0.8910, dev_loss=0.7269
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7394
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7409
# train_acc = 0.9922
# dev_acc = 0.8916, dev_loss=0.7418
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.7659
# train_acc = 1.0000
# dev_acc = 0.8923, dev_loss=0.7582
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7420
# train_acc = 0.9922
# dev_acc = 0.8871, dev_loss=0.7592
# train_acc = 0.9922
# dev_acc = 0.8876, dev_loss=0.7706
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7220
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7438
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.7388
# train_acc = 0.9922
# dev_acc = 0.8881, dev_loss=0.7776
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7549
# 42/100
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7537
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7502
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7630
# train_acc = 0.9844
# dev_acc = 0.8912, dev_loss=0.7579
# train_acc = 0.9922
# dev_acc = 0.8934, dev_loss=0.7173
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7087
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7286
# train_acc = 1.0000
# dev_acc = 0.8921, dev_loss=0.7111
# train_acc = 0.9922
# dev_acc = 0.8905, dev_loss=0.7420
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7400
# train_acc = 0.9844
# dev_acc = 0.8897, dev_loss=0.7479
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7371
# train_acc = 0.9922
# dev_acc = 0.8914, dev_loss=0.7520
# train_acc = 0.9922
# dev_acc = 0.8875, dev_loss=0.7568
# 43/100
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7526
# train_acc = 0.9922
# dev_acc = 0.8931, dev_loss=0.7268
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7256
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7372
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7563
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7599
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7405
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7593
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7758
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7725
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7765
# train_acc = 1.0000
# dev_acc = 0.8866, dev_loss=0.7752
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7483
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7382
# 44/100
# train_acc = 0.9922
# dev_acc = 0.8918, dev_loss=0.7562
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7882
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7745
# train_acc = 0.9922
# dev_acc = 0.8869, dev_loss=0.7919
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7886
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7695
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7695
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7519
# train_acc = 0.9922
# dev_acc = 0.8899, dev_loss=0.7591
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7572
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7772
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7565
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7584
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7566
# 45/100
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7579
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7817
# train_acc = 0.9922
# dev_acc = 0.8875, dev_loss=0.7711
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7806
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7672
# train_acc = 1.0000
# dev_acc = 0.8873, dev_loss=0.7660
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7596
# train_acc = 0.9922
# dev_acc = 0.8904, dev_loss=0.7725
# train_acc = 0.9844
# dev_acc = 0.8913, dev_loss=0.7713
# train_acc = 0.9922
# dev_acc = 0.8876, dev_loss=0.7826
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7530
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7520
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7676
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7650
# 46/100
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7428
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7534
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7728
# train_acc = 0.9922
# dev_acc = 0.8890, dev_loss=0.7818
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7830
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.8032
# train_acc = 0.9844
# dev_acc = 0.8902, dev_loss=0.7582
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7736
# train_acc = 1.0000
# dev_acc = 0.8924, dev_loss=0.7463
# train_acc = 0.9922
# dev_acc = 0.8909, dev_loss=0.7601
# train_acc = 1.0000
# dev_acc = 0.8937, dev_loss=0.7544
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7611
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7284
# train_acc = 1.0000
# dev_acc = 0.8911, dev_loss=0.7279
# 47/100
# train_acc = 0.9922
# dev_acc = 0.8929, dev_loss=0.7293
# train_acc = 0.9922
# dev_acc = 0.8933, dev_loss=0.7698
# train_acc = 1.0000
# dev_acc = 0.8940, dev_loss=0.7790
# train_acc = 0.9922
# dev_acc = 0.8926, dev_loss=0.7682
# train_acc = 0.9844
# dev_acc = 0.8881, dev_loss=0.7676
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7700
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7489
# train_acc = 0.9922
# dev_acc = 0.8904, dev_loss=0.7353
# train_acc = 0.9922
# dev_acc = 0.8861, dev_loss=0.7728
# train_acc = 0.9844
# dev_acc = 0.8879, dev_loss=0.7405
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7325
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7386
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7430
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7741
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7656
# 48/100
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7484
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7499
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7448
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7510
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7615
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7696
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7854
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7580
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7367
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7255
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7648
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7550
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7846
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7592
# 49/100
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7547
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7468
# train_acc = 0.9844
# dev_acc = 0.8905, dev_loss=0.7309
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7468
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7273
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7522
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7838
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7737
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7471
# train_acc = 0.9844
# dev_acc = 0.8888, dev_loss=0.7695
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7458
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7475
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7671
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7548
# 50/100
# train_acc = 0.9844
# dev_acc = 0.8897, dev_loss=0.7468
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7182
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7510
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7590
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7317
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7250
# train_acc = 1.0000
# dev_acc = 0.8868, dev_loss=0.7305
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7703
# train_acc = 1.0000
# dev_acc = 0.8858, dev_loss=0.7769
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.7815
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7781
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7968
# train_acc = 1.0000
# dev_acc = 0.8864, dev_loss=0.7580
# train_acc = 0.9766
# dev_acc = 0.8861, dev_loss=0.7439
# 51/100
# train_acc = 0.9922
# dev_acc = 0.8871, dev_loss=0.7435
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.7487
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7640
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7928
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.7945
# train_acc = 1.0000
# dev_acc = 0.8865, dev_loss=0.8047
# train_acc = 1.0000
# dev_acc = 0.8866, dev_loss=0.7865
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.7758
# train_acc = 1.0000
# dev_acc = 0.8862, dev_loss=0.7626
# train_acc = 1.0000
# dev_acc = 0.8862, dev_loss=0.7703
# train_acc = 0.9844
# dev_acc = 0.8872, dev_loss=0.7806
# train_acc = 0.9922
# dev_acc = 0.8861, dev_loss=0.7932
# train_acc = 0.9844
# dev_acc = 0.8901, dev_loss=0.7473
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7594
# 52/100
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7631
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7869
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7668
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7611
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7811
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7474
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7473
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7468
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7419
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7629
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.7782
# train_acc = 1.0000
# dev_acc = 0.8852, dev_loss=0.7756
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7613
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7937
# 53/100
# train_acc = 0.9922
# dev_acc = 0.8895, dev_loss=0.7963
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.8061
# train_acc = 1.0000
# dev_acc = 0.8863, dev_loss=0.7830
# train_acc = 1.0000
# dev_acc = 0.8869, dev_loss=0.7754
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7754
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7636
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7640
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7894
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7744
# train_acc = 0.9922
# dev_acc = 0.8873, dev_loss=0.7892
# train_acc = 0.9844
# dev_acc = 0.8892, dev_loss=0.7548
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7991
# train_acc = 0.9922
# dev_acc = 0.8905, dev_loss=0.7773
# train_acc = 0.9922
# dev_acc = 0.8920, dev_loss=0.7939
# 54/100
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7896
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7763
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.7764
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7649
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7445
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7590
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7878
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7751
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7588
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7625
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7527
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.7432
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7468
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7324
# 55/100
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7483
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7760
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7428
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7590
# train_acc = 1.0000
# dev_acc = 0.8873, dev_loss=0.7967
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7816
# train_acc = 0.9922
# dev_acc = 0.8870, dev_loss=0.7957
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7673
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7767
# train_acc = 1.0000
# dev_acc = 0.8876, dev_loss=0.7616
# train_acc = 1.0000
# dev_acc = 0.8859, dev_loss=0.7696
# train_acc = 0.9922
# dev_acc = 0.8870, dev_loss=0.7641
# train_acc = 1.0000
# dev_acc = 0.8867, dev_loss=0.7746
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7733
# 56/100
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7683
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7672
# train_acc = 0.9844
# dev_acc = 0.8884, dev_loss=0.7732
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.7598
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7737
# train_acc = 1.0000
# dev_acc = 0.8870, dev_loss=0.7791
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7660
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.7502
# train_acc = 1.0000
# dev_acc = 0.8913, dev_loss=0.7584
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7913
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7762
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7431
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7531
# train_acc = 1.0000
# dev_acc = 0.8861, dev_loss=0.7380
# 57/100
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7340
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7785
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7718
# train_acc = 1.0000
# dev_acc = 0.8860, dev_loss=0.7762
# train_acc = 0.9922
# dev_acc = 0.8858, dev_loss=0.7710
# train_acc = 1.0000
# dev_acc = 0.8869, dev_loss=0.7617
# train_acc = 1.0000
# dev_acc = 0.8842, dev_loss=0.7757
# train_acc = 1.0000
# dev_acc = 0.8857, dev_loss=0.7789
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7702
# train_acc = 0.9609
# dev_acc = 0.8894, dev_loss=0.7663
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7371
# train_acc = 0.9922
# dev_acc = 0.8916, dev_loss=0.7396
# train_acc = 0.9922
# dev_acc = 0.8931, dev_loss=0.7469
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.7471
# 58/100
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7562
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7737
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7542
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7389
# train_acc = 1.0000
# dev_acc = 0.8913, dev_loss=0.7593
# train_acc = 1.0000
# dev_acc = 0.8872, dev_loss=0.7637
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7975
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7718
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7695
# train_acc = 0.9922
# dev_acc = 0.8876, dev_loss=0.7880
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7968
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.7931
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7870
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7732
# 59/100
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7341
# train_acc = 0.9922
# dev_acc = 0.8894, dev_loss=0.7553
# train_acc = 0.9844
# dev_acc = 0.8915, dev_loss=0.7319
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7458
# train_acc = 0.9922
# dev_acc = 0.8913, dev_loss=0.7389
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.7314
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7212
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7433
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7770
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7723
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7609
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7524
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7520
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7396
# 60/100
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7461
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7418
# train_acc = 0.9844
# dev_acc = 0.8888, dev_loss=0.7636
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7516
# train_acc = 0.9844
# dev_acc = 0.8906, dev_loss=0.7659
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7722
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7709
# train_acc = 0.9922
# dev_acc = 0.8876, dev_loss=0.7804
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7575
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7663
# train_acc = 1.0000
# dev_acc = 0.8922, dev_loss=0.7510
# train_acc = 0.9922
# dev_acc = 0.8904, dev_loss=0.7197
# train_acc = 0.9922
# dev_acc = 0.8865, dev_loss=0.7463
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7294
# 61/100
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7375
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7395
# train_acc = 0.9922
# dev_acc = 0.8917, dev_loss=0.7493
# train_acc = 0.9922
# dev_acc = 0.8929, dev_loss=0.7797
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7708
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7604
# train_acc = 0.9922
# dev_acc = 0.8909, dev_loss=0.7522
# train_acc = 0.9844
# dev_acc = 0.8934, dev_loss=0.7470
# train_acc = 0.9922
# dev_acc = 0.8938, dev_loss=0.7507
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7628
# train_acc = 1.0000
# dev_acc = 0.8933, dev_loss=0.7667
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7805
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7725
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7722
# 62/100
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7706
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7384
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.7240
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7400
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7554
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.7812
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7414
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7661
# train_acc = 1.0000
# dev_acc = 0.8921, dev_loss=0.7655
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7719
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7721
# train_acc = 0.9922
# dev_acc = 0.8867, dev_loss=0.7473
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7843
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7731
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.7855
# 63/100
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7801
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7893
# train_acc = 1.0000
# dev_acc = 0.8922, dev_loss=0.7698
# train_acc = 0.9922
# dev_acc = 0.8922, dev_loss=0.7569
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7645
# train_acc = 0.9922
# dev_acc = 0.8906, dev_loss=0.7668
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7720
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7798
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7650
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7810
# train_acc = 1.0000
# dev_acc = 0.8868, dev_loss=0.7894
# train_acc = 0.9922
# dev_acc = 0.8894, dev_loss=0.7721
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7750
# train_acc = 1.0000
# ...
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7256
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7330
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7380
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7284
# 79/100
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7385
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7519
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7899
# train_acc = 0.9844
# dev_acc = 0.8869, dev_loss=0.7858
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7714
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7904
# train_acc = 1.0000
# dev_acc = 0.8895, dev_loss=0.7870
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7841
# train_acc = 0.9844
# dev_acc = 0.8903, dev_loss=0.7902
# train_acc = 0.9844
# dev_acc = 0.8911, dev_loss=0.7662
# train_acc = 0.9922
# dev_acc = 0.8914, dev_loss=0.7567
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7495
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7682
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7749
# 80/100
# train_acc = 1.0000
# dev_acc = 0.8927, dev_loss=0.7706
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7430
# train_acc = 1.0000
# dev_acc = 0.8944, dev_loss=0.7566
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.7587
# train_acc = 0.9922
# dev_acc = 0.8920, dev_loss=0.7439
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7562
# train_acc = 1.0000
# dev_acc = 0.8928, dev_loss=0.7489
# train_acc = 0.9922
# dev_acc = 0.8931, dev_loss=0.7541
# train_acc = 0.9922
# dev_acc = 0.8919, dev_loss=0.7641
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7550
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7366
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7281
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7428
# train_acc = 1.0000
# dev_acc = 0.8938, dev_loss=0.7393
# 81/100
# train_acc = 1.0000
# dev_acc = 0.8926, dev_loss=0.7383
# train_acc = 0.9922
# dev_acc = 0.8915, dev_loss=0.7560
# train_acc = 1.0000
# dev_acc = 0.8948, dev_loss=0.7515
# train_acc = 1.0000
# dev_acc = 0.8931, dev_loss=0.7628
# train_acc = 0.9922
# dev_acc = 0.8932, dev_loss=0.7692
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.7624
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7599
# train_acc = 1.0000
# dev_acc = 0.8922, dev_loss=0.7528
# train_acc = 0.9922
# dev_acc = 0.8914, dev_loss=0.7599
# train_acc = 1.0000
# dev_acc = 0.8921, dev_loss=0.7605
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7613
# train_acc = 0.9922
# dev_acc = 0.8895, dev_loss=0.7663
# train_acc = 1.0000
# dev_acc = 0.8922, dev_loss=0.7805
# train_acc = 1.0000
# dev_acc = 0.8937, dev_loss=0.7674
# 82/100
# train_acc = 1.0000
# dev_acc = 0.8934, dev_loss=0.7727
# train_acc = 1.0000
# dev_acc = 0.8938, dev_loss=0.7487
# train_acc = 0.9922
# dev_acc = 0.8929, dev_loss=0.7501
# train_acc = 0.9844
# dev_acc = 0.8920, dev_loss=0.7499
# train_acc = 1.0000
# dev_acc = 0.8928, dev_loss=0.7825
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7388
# train_acc = 0.9922
# dev_acc = 0.8915, dev_loss=0.7413
# train_acc = 0.9922
# dev_acc = 0.8898, dev_loss=0.7404
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7454
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7478
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7463
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7409
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7697
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7538
# 83/100
# train_acc = 1.0000
# dev_acc = 0.8940, dev_loss=0.7243
# train_acc = 0.9844
# dev_acc = 0.8928, dev_loss=0.7297
# train_acc = 0.9922
# dev_acc = 0.8892, dev_loss=0.7343
# train_acc = 0.9844
# dev_acc = 0.8908, dev_loss=0.7518
# train_acc = 0.9922
# dev_acc = 0.8932, dev_loss=0.7507
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7640
# train_acc = 0.9844
# dev_acc = 0.8913, dev_loss=0.7542
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7720
# train_acc = 0.9844
# dev_acc = 0.8899, dev_loss=0.7600
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7511
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7700
# train_acc = 0.9922
# dev_acc = 0.8916, dev_loss=0.7717
# train_acc = 0.9922
# dev_acc = 0.8934, dev_loss=0.7567
# train_acc = 0.9922
# dev_acc = 0.8918, dev_loss=0.7530
# 84/100
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7446
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7732
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7839
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.7565
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7715
# train_acc = 1.0000
# dev_acc = 0.8881, dev_loss=0.7777
# train_acc = 0.9688
# dev_acc = 0.8879, dev_loss=0.7754
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7689
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7775
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7666
# train_acc = 0.9922
# dev_acc = 0.8899, dev_loss=0.7521
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7493
# train_acc = 0.9844
# dev_acc = 0.8879, dev_loss=0.7609
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.7884
# 85/100
# train_acc = 0.9922
# dev_acc = 0.8861, dev_loss=0.8123
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7967
# train_acc = 1.0000
# dev_acc = 0.8880, dev_loss=0.8005
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.8050
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7701
# train_acc = 0.9922
# dev_acc = 0.8897, dev_loss=0.8010
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.8069
# train_acc = 0.9844
# dev_acc = 0.8888, dev_loss=0.8208
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.8031
# train_acc = 1.0000
# dev_acc = 0.8877, dev_loss=0.8028
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7967
# train_acc = 0.9844
# dev_acc = 0.8901, dev_loss=0.7640
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7611
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7830
# 86/100
# train_acc = 0.9844
# dev_acc = 0.8890, dev_loss=0.7755
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.7598
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7836
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.8035
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.8079
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.8123
# train_acc = 1.0000
# dev_acc = 0.8871, dev_loss=0.7723
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7745
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7887
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7920
# train_acc = 1.0000
# dev_acc = 0.8890, dev_loss=0.7904
# train_acc = 0.9922
# dev_acc = 0.8877, dev_loss=0.7782
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7915
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7787
# 87/100
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7774
# train_acc = 0.9844
# dev_acc = 0.8914, dev_loss=0.7733
# train_acc = 0.9922
# dev_acc = 0.8902, dev_loss=0.7467
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7620
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7735
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.7757
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7755
# train_acc = 0.9844
# dev_acc = 0.8919, dev_loss=0.7586
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.7625
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7625
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7595
# train_acc = 0.9922
# dev_acc = 0.8894, dev_loss=0.7860
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7809
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7679
# 88/100
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7765
# train_acc = 0.9922
# dev_acc = 0.8868, dev_loss=0.7753
# train_acc = 1.0000
# dev_acc = 0.8875, dev_loss=0.7541
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7670
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7666
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7921
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7818
# train_acc = 1.0000
# dev_acc = 0.8870, dev_loss=0.8156
# train_acc = 0.9922
# dev_acc = 0.8897, dev_loss=0.7930
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7906
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7986
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.8033
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.8141
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.8183
# 89/100
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.8172
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.8125
# train_acc = 0.9922
# dev_acc = 0.8906, dev_loss=0.8206
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.8199
# train_acc = 0.9922
# dev_acc = 0.8911, dev_loss=0.8045
# train_acc = 1.0000
# dev_acc = 0.8931, dev_loss=0.7701
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.7847
# train_acc = 0.9922
# dev_acc = 0.8924, dev_loss=0.7704
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7631
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7736
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7996
# train_acc = 0.9922
# dev_acc = 0.8900, dev_loss=0.7700
# train_acc = 1.0000
# dev_acc = 0.8918, dev_loss=0.7708
# train_acc = 0.9922
# dev_acc = 0.8917, dev_loss=0.7750
# 90/100
# train_acc = 1.0000
# dev_acc = 0.8917, dev_loss=0.8055
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7797
# train_acc = 1.0000
# dev_acc = 0.8914, dev_loss=0.7632
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7660
# train_acc = 0.9844
# dev_acc = 0.8870, dev_loss=0.7625
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.7456
# train_acc = 0.9922
# dev_acc = 0.8877, dev_loss=0.7784
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7592
# train_acc = 0.9844
# dev_acc = 0.8878, dev_loss=0.7691
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7718
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7815
# train_acc = 0.9922
# dev_acc = 0.8893, dev_loss=0.7834
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7666
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7926
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.8004
# 91/100
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.7669
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7843
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7786
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7587
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7630
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7585
# train_acc = 1.0000
# dev_acc = 0.8915, dev_loss=0.7645
# train_acc = 1.0000
# dev_acc = 0.8924, dev_loss=0.7418
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.7533
# train_acc = 0.9922
# dev_acc = 0.8932, dev_loss=0.7699
# train_acc = 0.9922
# dev_acc = 0.8933, dev_loss=0.7736
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7570
# train_acc = 0.9844
# dev_acc = 0.8935, dev_loss=0.7492
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7666
# 92/100
# train_acc = 1.0000
# dev_acc = 0.8904, dev_loss=0.7613
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7599
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7642
# train_acc = 1.0000
# dev_acc = 0.8911, dev_loss=0.7670
# train_acc = 0.9922
# dev_acc = 0.8901, dev_loss=0.7804
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7910
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7980
# train_acc = 1.0000
# dev_acc = 0.8909, dev_loss=0.8194
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.8264
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7900
# train_acc = 1.0000
# dev_acc = 0.8884, dev_loss=0.7900
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7841
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7834
# train_acc = 0.9922
# dev_acc = 0.8860, dev_loss=0.7847
# 93/100
# train_acc = 1.0000
# dev_acc = 0.8883, dev_loss=0.7738
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7831
# train_acc = 0.9922
# dev_acc = 0.8886, dev_loss=0.7464
# train_acc = 0.9922
# dev_acc = 0.8874, dev_loss=0.7904
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7867
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7758
# train_acc = 0.9844
# dev_acc = 0.8883, dev_loss=0.7623
# train_acc = 1.0000
# dev_acc = 0.8921, dev_loss=0.7732
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7751
# train_acc = 0.9844
# dev_acc = 0.8906, dev_loss=0.7783
# train_acc = 1.0000
# dev_acc = 0.8901, dev_loss=0.7628
# train_acc = 0.9844
# dev_acc = 0.8879, dev_loss=0.7863
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7654
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7808
# 94/100
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.8072
# train_acc = 0.9844
# dev_acc = 0.8892, dev_loss=0.7958
# train_acc = 0.9844
# dev_acc = 0.8900, dev_loss=0.8084
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.8216
# train_acc = 0.9922
# dev_acc = 0.8907, dev_loss=0.8122
# train_acc = 0.9922
# dev_acc = 0.8883, dev_loss=0.8076
# train_acc = 0.9922
# dev_acc = 0.8909, dev_loss=0.7763
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.7818
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7807
# train_acc = 1.0000
# dev_acc = 0.8882, dev_loss=0.7604
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7787
# train_acc = 0.9922
# dev_acc = 0.8889, dev_loss=0.7868
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7557
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7584
# 95/100
# train_acc = 0.9844
# dev_acc = 0.8898, dev_loss=0.7744
# train_acc = 1.0000
# dev_acc = 0.8910, dev_loss=0.7817
# train_acc = 1.0000
# dev_acc = 0.8893, dev_loss=0.7718
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.7809
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7996
# train_acc = 0.9922
# dev_acc = 0.8923, dev_loss=0.7807
# train_acc = 1.0000
# dev_acc = 0.8870, dev_loss=0.7897
# train_acc = 0.9922
# dev_acc = 0.8882, dev_loss=0.7748
# train_acc = 0.9922
# dev_acc = 0.8885, dev_loss=0.7666
# train_acc = 1.0000
# dev_acc = 0.8885, dev_loss=0.7705
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7675
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7986
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.8003
# train_acc = 0.9922
# dev_acc = 0.8887, dev_loss=0.7849
# 96/100
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.8010
# train_acc = 0.9922
# dev_acc = 0.8908, dev_loss=0.7864
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7861
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7972
# train_acc = 1.0000
# dev_acc = 0.8898, dev_loss=0.8100
# train_acc = 1.0000
# dev_acc = 0.8908, dev_loss=0.8185
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.7982
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.8239
# train_acc = 0.9922
# dev_acc = 0.8878, dev_loss=0.8313
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.8006
# train_acc = 1.0000
# dev_acc = 0.8887, dev_loss=0.8043
# train_acc = 0.9922
# dev_acc = 0.8890, dev_loss=0.8033
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7958
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7810
# 97/100
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7746
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7479
# train_acc = 1.0000
# dev_acc = 0.8906, dev_loss=0.7527
# train_acc = 0.9922
# dev_acc = 0.8912, dev_loss=0.7642
# train_acc = 0.9922
# dev_acc = 0.8909, dev_loss=0.7854
# train_acc = 1.0000
# dev_acc = 0.8889, dev_loss=0.7773
# train_acc = 1.0000
# dev_acc = 0.8891, dev_loss=0.7576
# train_acc = 1.0000
# dev_acc = 0.8903, dev_loss=0.7777
# train_acc = 1.0000
# dev_acc = 0.8897, dev_loss=0.7799
# train_acc = 1.0000
# dev_acc = 0.8912, dev_loss=0.7489
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7816
# train_acc = 0.9844
# dev_acc = 0.8916, dev_loss=0.7829
# train_acc = 1.0000
# dev_acc = 0.8919, dev_loss=0.7712
# train_acc = 0.9766
# dev_acc = 0.8908, dev_loss=0.7610
# 98/100
# train_acc = 1.0000
# dev_acc = 0.8900, dev_loss=0.7533
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7741
# train_acc = 0.9922
# dev_acc = 0.8929, dev_loss=0.7736
# train_acc = 1.0000
# dev_acc = 0.8886, dev_loss=0.7985
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.7778
# train_acc = 1.0000
# dev_acc = 0.8894, dev_loss=0.7946
# train_acc = 1.0000
# dev_acc = 0.8899, dev_loss=0.7921
# train_acc = 1.0000
# dev_acc = 0.8879, dev_loss=0.7942
# train_acc = 1.0000
# dev_acc = 0.8905, dev_loss=0.8129
# train_acc = 1.0000
# dev_acc = 0.8916, dev_loss=0.8171
# train_acc = 1.0000
# dev_acc = 0.8874, dev_loss=0.8124
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7847
# train_acc = 0.9922
# dev_acc = 0.8903, dev_loss=0.7959
# train_acc = 0.9844
# dev_acc = 0.8892, dev_loss=0.7847
# 99/100
# train_acc = 1.0000
# dev_acc = 0.8907, dev_loss=0.7927
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.8070
# train_acc = 1.0000
# dev_acc = 0.8892, dev_loss=0.7875
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7796
# train_acc = 0.9766
# dev_acc = 0.8902, dev_loss=0.7744
# train_acc = 0.9922
# dev_acc = 0.8891, dev_loss=0.7735
# train_acc = 0.9922
# dev_acc = 0.8896, dev_loss=0.7593
# train_acc = 1.0000
# dev_acc = 0.8902, dev_loss=0.7903
# train_acc = 1.0000
# dev_acc = 0.8888, dev_loss=0.7798
# train_acc = 0.9922
# dev_acc = 0.8865, dev_loss=0.8037
# train_acc = 0.9922
# dev_acc = 0.8881, dev_loss=0.8037
# train_acc = 1.0000
# dev_acc = 0.8878, dev_loss=0.7957
# train_acc = 0.9844
# dev_acc = 0.8877, dev_loss=0.8059
# train_acc = 1.0000
# dev_acc = 0.8896, dev_loss=0.7896

# %%
import numpy as np
def evalute(model, data_dl, test=False):
    model.eval()
    loss_total = 0
    predict_all = np.array([], dtype = int)
    labels_all = np.array([], dtype=int)
    with torch.no_grad():
        for texts, labels in data_dl:
            outputs = model(texts)
            loss = F.cross_entropy(outputs, labels)
            loss_total += loss
            labels = labels.data.cpu()
            predict = torch.max(outputs.data.cpu(), 1)[1].cpu().numpy()
            labels_all = np.append(labels_all, labels)
            predict_all = np.append(predict_all, predict)
            
        acc = metrics.accuracy_score(labels_all, predict_all)
        
    return acc, loss_total / len(data_dl)

# %%
# x = (torch.rand(1, 32, embeding_pretrained.size(1)).to(device), torch.LongTensor([1]).to(device))
x
with SummaryWriter(comment='Net1') as w:
    w.add_graph(model_rt, (x,))
# Out:
# /home/andy/anaconda3/envs/py39/lib/python3.9/site-packages/torch/nn/modules/rnn.py:204: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.input_size != input.size(-1):
# /home/andy/anaconda3/envs/py39/lib/python3.9/site-packages/torch/nn/modules/rnn.py:225: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if hx.size() != expected_hidden_size:

# %%
# Out:
# (tensor([[[                  1,      94149973749648,                  24,
#             ...,      94149973751056, 8243124912085009483,
#                 94149973751088],
#           [7016431369869852682,      94149973751184, 4193527942359286840,
#             ...,      94149973751088,      94149973752448,
#            3268325118455054353],
#           [     94149887632056,      94149973752792,                   0,
#             ..., 5575186034917900313,      94149973754392,
#            3180189357294223361],
#           ...,
#           [8387201278994620457, 3327632609719377755, 7305999817851800110,
#             ..., 7214801925396114990, 8316288633764079205,
#            7310231100686167914],
#           [5269275830158911084, 6585789199896700276, 2317486216248775775,
#             ..., 2314885530453827951, 7955995078896805220,
#            7810775745979970665],
#           [8390876208520244326, 8295679392196665402, 8389758742978129780,
#             ..., 2916483597133571428, 7089073068528197471,
#            8243122550393693548]]]),
#  tensor([1]))

# %%
for x, label in train_dl:
    print(x)
    break
# Out:
# (tensor([[   5,  167,    2,  ..., 4760, 4760, 4760],
#         [  20, 1473, 1456,  ..., 4760, 4760, 4760],
#         [ 217,  647,    4,  ..., 4760, 4760, 4760],
#         ...,
#         [ 220,  617,   15,  ..., 4760, 4760, 4760],
#         [  14,    6,   54,  ..., 4760, 4760, 4760],
#         [  20,  435,  979,  ..., 4760, 4760, 4760]], device='cuda:0'), tensor([32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
#         32, 32], device='cuda:0'))
